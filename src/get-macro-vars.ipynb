# %% [markdown]
# ## Sourcing Macro Variable
#
# from the FRED API

# %%
import pandas as pd
import numpy as np
from fredapi import Fred # see documentation here (incl. vintages) https://pypi.org/project/fredapi/

# %%
key = "182161f35ab1b0231ab7a21e3b991a52"
fred = Fred(key)

# %% [markdown]
# **Which macro variables could be of interest to us?**
#
# - Inflation (monthly)
# - GDP (quarterly)
# - Daily Exchange Rates
#     - EUR
#     - GBP
#     - YEN
# - FFR (daily)
# - SOFR (daily)
# - Employment & Job Openings (monthly)
# - yield curve (daily)
# - fed assets (weekly)
# - sentiment indicator (monthly)
# - industrial production index (daily)
#
#
#
# **Leider ist daily die Max. Frequency** d.h. wenn es 2 oder mehr speeches an einem Tag gibt, können wir diese nicht mit den macro daten alignen (as is)
#
# **For Forecasting:** As soon as we want vintages, we can get either specific version from specific dates, or all vintages (check pkg documentation from above)

# %%
# CPI in total 
cpi = fred.get_series("CPALTT01USM657N")
# cpi.head()
cpi.tail()

# fed's preferred inflation metric 
# Personal Consumption Expenditures Price Index
pcepi = fred.get_series('PCEPI')
pcepi.tail()
# Out:
# 2023-11-01   -0.201514
# 2023-12-01   -0.099332
# 2024-01-01    0.544750
# 2024-02-01    0.618967
# 2024-03-01    0.646417
# dtype: float64

# %%
gdp = fred.get_series('GDP')
gdp.tail()
# Out:
# 2024-10-01    29825.182
# 2025-01-01    30042.113
# 2025-04-01    30485.729
# 2025-07-01    31098.027
# 2025-10-01    31442.483
# dtype: float64

# %%
# exchange rates daily
eur = fred.get_series('DEXUSEU')
gbp = fred.get_series('DEXUSUK')
yen = fred.get_series('DEXJPUS')

# %%
# other high-frequency vars

# (effective) federal funds rate
ffr = fred.get_series('DFF')

# Secured Overnight financing rate (SOFR) index
sofr = fred.get_series('SOFRINDEX')

# %% [markdown]
# #### Employment Stats

# %%
# Total Nonfarm Payrolls
# a measure of the number of U.S. workers in the economy
payems = fred.get_series('PAYEMS')

# Job Openings: Total Nonfarm
jtsjol = fred.get_series('JTSJOL')

# %% [markdown]
# #### Financial

# %%
# 10-Year Treasury Constant Maturity Minus 2-Year Treasury Constant Maturity
t10y2y = fred.get_series('T10Y2Y')

# (Total Assets - Federal Reserve Balance Sheet)
waclc = fred.get_series('WALCL')

# %% [markdown]
# ### Sentiment Indicators

# %%
# University of Michigan Sentiment Index
umcsent = fred.get_series('UMCSENT')

# Industrial Production Index
indpro = fred.get_series('INDPRO')

# %%
umcsent

# %%
# assemble into quarterly, monthly, daily and weekly df
qrt_series = [gdp]
monthly_series = [cpi, pcepi, payems, jtsjol, t10y2y, umcsent, indpro]
daily_series = [eur, gbp, yen, ffr, sofr]
weekly_series = [waclc]

# create df for each frequency
qrt_df = pd.concat(qrt_series, axis=1)
monthly_df = pd.concat(monthly_series, axis=1)
daily_df = pd.concat(daily_series, axis=1)
weekly_df = pd.concat(weekly_series, axis=1)

# writing to csv
qrt_df.to_csv('../data/macro-vars-quarterly.csv')
monthly_df.to_csv('../data/macro-vars-monthly.csv')
daily_df.to_csv('../data/macro-vars-daily.csv')
weekly_df.to_csv('../data/macro-vars-weekly.csv')
# Out:
# /var/folders/4q/6lp_9hnn0zn9_q873pjzdtm40000gn/T/ipykernel_44787/2528245382.py:9: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   monthly_df = pd.concat(monthly_series, axis=1)
# /var/folders/4q/6lp_9hnn0zn9_q873pjzdtm40000gn/T/ipykernel_44787/2528245382.py:10: Pandas4Warning: Sorting by default when concatenating all DatetimeIndex is deprecated.  In the future, pandas will respect the default of `sort=False`. Specify `sort=True` or `sort=False` to silence this message. If you see this warnings when not directly calling concat, report a bug to pandas.
#   daily_df = pd.concat(daily_series, axis=1)
